# %%
#Import library numpy, pandas dan scikit-learn
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#Membaca Dataset dari File ke Pandas dataFrame
data = pd.read_csv('Dataset tenis.csv', delimiter=';', header=0)

# %%
le = preprocessing.LabelEncoder()
data_encoded = data.apply(le.fit_transform)

# %%
features = data_encoded.drop('PLAY', axis=1)
target = data_encoded['PLAY']

# %%
train_features, test_features, train_target, test_target = train_test_split(features, target, test_size=2, random_state=42)

# %%
#Mendefinisikan Decision Tree Classifier
model = DecisionTreeClassifier()

# %%
#Mentraining Model
model = model.fit(features, target)

# %%
#Memprediksi Input Data Testing
hasilPrediksi = model.predict(test_features)
print("Label Sebenarnya : ", test_target)
print("Hasil Prediksi : ", hasilPrediksi)
# Out:
# Label Sebenarnya :  9     1
# 11    1
# Name: PLAY, dtype: int64
# Hasil Prediksi :  [1 1]

# %%
#Menghitung Akurasi
prediksiBenar = (hasilPrediksi == labelTesting).sum()
prediksiSalah = (hasilPrediksi != labelTesting).sum()
print("Prediksi Benar :", prediksiBenar, "data")
print("Prediksi Salah :", prediksiSalah, "data")
print("Akurasi :", prediksiBenar/(prediksiBenar+prediksiSalah) * 100, "%")
# Out:
# Prediksi Benar : 2 data
# Prediksi Salah : 0 data
# Akurasi : 100.0 %

# %%
# Membuat grafik
feature_names = list(features.columns)
class_names = list(le.classes_)

fig = plt.figure(figsize=(8, 8))
_ = tree.plot_tree(model, feature_names=feature_names, class_names=class_names, filled=True)

plt.show()
